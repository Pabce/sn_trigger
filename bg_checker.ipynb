# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors

from parameters import *
import save_n_load as sl
import clustering as cl
import hit_stat as hs
import aux

bg_data_dir = BG_DATA_DIR

bg_types_vd = BG_TYPES#["Ar39GenInLAr", "Kr85GenInLAr", "NeutronGenInRock", "Rn222ChainGenInLAr"]

bg_data_dir_0 = "/eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/"
#bg_data_dir = "/eos/project-e/ep-nu/pbarhama/sn_saves/new_photon_lib_prod_background_pds/"
#bg_data_dir_0 = "/eos/project-e/ep-nu/pbarhama/sn_saves/hd_prod_background_pds/"

adc_mode = "normal"
sim_mode = "xe"
bg_types = ["Ar39GenInLAr", "Kr85GenInLAr"]#, "Rn222ChainRn222GenInLAr", "NeutronGenInRock"]

# %%
bg_limit = 30
bg_sample_length = 8.5#4.492 #8.5 # in ms
bg_lenght = bg_limit * bg_sample_length * 20

bg_total_hits, bg_hit_list_per_event, _, bg_total_hits_per_type, bg_hit_list_per_event_per_type =\
                                    sl.load_all_backgrounds_chunky_type_separated(limit=bg_limit, detector="VD", bg_data_dir=bg_data_dir_0, adc_mode=adc_mode,
                                            sim_mode=sim_mode, offset=2, bg_types=bg_types);

bg_total_hits_ar, bg_hit_list_per_event_ar, _, bg_total_hits_per_type_ar, bg_hit_list_per_event_per_type_ar =\
        sl.load_all_backgrounds_chunky_type_separated(limit=bg_limit, detector="VD", bg_data_dir=BG_DATA_DIR, adc_mode=adc_mode,
                                        sim_mode="xe", offset=2, bg_types=bg_types_vd);
# Out:
# prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1458' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1464' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1457' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1459' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1461' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1460' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1465' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1463' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1466' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1462' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1472' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1469' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1471' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1468' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1470' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1467' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1464' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1461' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1462' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1468' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1458' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1471' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1466' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1460' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1457' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1463' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1469' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1472' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1470' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1467' parent=512 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1478' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1482' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1473' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1475' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1474' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1479' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1476' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1483' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1477' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1480' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1484' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1481' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1485' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1486' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1488' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1487' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1483' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1477' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1474' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1476' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1478' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1482' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1473' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1484' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1480' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1479' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1475' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1485' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1481' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1487' parent=512 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1490' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1494' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1497' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1491' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1496' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1495' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1493' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1499' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1500' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1492' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1498' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1502' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1489' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1501' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1504' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1503' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1503' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1504' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1500' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1501' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1495' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1493' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1492' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1496' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1497' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1491' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1502' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1499' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1494' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1498' parent=512 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1505' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1506' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1507' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1513' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1514' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1511' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1509' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1516' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1519' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1520' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1510' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1515' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1517' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1518' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1512' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1508' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1509' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1513' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1508' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1512' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1511' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1505' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1506' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1510' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1519' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1518' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1507' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1515' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1514' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1520' parent=512 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1528' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1524' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1531' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1522' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1530' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1525' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1533' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1527' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1536' parent=512 started daemon>
# ...
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1674' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1679' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1677' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1680' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1678' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1674' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1673' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1675' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1668' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1666' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1677' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1672' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1678' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1670' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1676' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1671' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1665' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1669' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_NeutronGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1680' parent=512 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_GammasGenInRock_g4_detsim_xe_reco_hist.root
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005054.208160562_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1681' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.132295532_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1683' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1682' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.411514466_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1684' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.418078211_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1687' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005056.930465710_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1685' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1686' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.923380112_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1688' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.993127433_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1689' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.222771391_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1691' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.038665265_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1690' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1693' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.683811342_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1696' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.625466176_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1694' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.646150220_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1695' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1692' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005060.487090808_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1683' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.811803394_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1682' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.214806115_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1690' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1685' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.078067980_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1684' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1686' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.730902302_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1681' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.572209385_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1687' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1689' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005064.854690735_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1692' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005065.366943358_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1695' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.439489243_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1694' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.996261572_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1693' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005066.136417073_GammasGenInRock_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-1688' parent=512 started daemon>

# %%
# %matplotlib widget

plot="xe"

fig = plt.figure(1)
ax = fig.add_subplot(111)

fig2 = plt.figure(2)
ax2 = fig2.add_subplot(111)

NUM_COLORS = 13
cm = plt.get_cmap('tab20b')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
ax.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

#NUM_ARAPUCAS = 184
NUM_ARAPUCAS = 480 # For HD

ax.set_xlabel("Number of hits per ms / arapuca")
ax.set_xscale('log')
ax2.set_xlabel("Number of hits per ms / arapuca ")
ax2.set_xscale('log')
#ax.set_xlim(left=0.5, right=1000)

for i, type in enumerate(bg_types):
    print(i, type)
    
    total_len = 0
    lens = []
    total_len_ar = 0
    lens_ar = []
    
    for hit_list in bg_hit_list_per_event_per_type[i]:
        total_len += len(hit_list)
        lens.append(len(hit_list))
    for hit_list in bg_hit_list_per_event_per_type_ar[i]:
        total_len_ar += len(hit_list)
        lens_ar.append(len(hit_list))
    
    average_len = total_len / len(bg_hit_list_per_event_per_type[i])
    rate = average_len / bg_sample_length * 1/NUM_ARAPUCAS
    
    average_len_ar = total_len_ar / len(bg_hit_list_per_event_per_type_ar[i])
    rate_ar = average_len_ar / bg_sample_length * 1/NUM_ARAPUCAS
    
    if rate < 1:
        ax.hist(np.array(lens) / bg_sample_length /NUM_ARAPUCAS, bins=np.linspace(0.01, 1, 70), label=type, density=True)
    if rate >= 0.01 and (plot=="BOTH" or plot=="xe"):
        ax2.hist(np.array(lens) / bg_sample_length / NUM_ARAPUCAS, bins=np.linspace(0.01, 2, 300), label=type, density=True)
    #ax.hist(np.array(lens) / bg_sample_length, bins=np.logspace(-1, 2, 40), label=type, density=True)
    if rate_ar >= 0.1 and (plot=="BOTH" or plot=="aronly"):
        ax2.hist(np.array(lens_ar) / bg_sample_length, bins=np.linspace(3, 300, 300), label=type + " (Ar)")#, density=True, histtype='step')#, linestyle='dashed')
    
    print(rate, "(hits per ms / arapuca)")
    print("Min:", np.min(lens)/bg_sample_length, "Max:", np.max(lens)/bg_sample_length)
    print(rate_ar, "(hits per ms / arapuca) ArOnly")

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

box = ax2.get_position()
ax2.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 0 Ar39GenInLAr
# 0.576297385620915 (hits per ms / arapuca)
# Min: 255.52941176470588 Max: 297.88235294117646
# 0.576297385620915 (hits per ms / arapuca) ArOnly
# 1 Kr85GenInLAr
# 0.06086723856209151 (hits per ms / arapuca)
# Min: 23.058823529411764 Max: 34.8235294117647
# 0.06086723856209151 (hits per ms / arapuca) ArOnly

# %%
# What about the average PEs for each of these BG types?
for i, type in enumerate(bg_types):
    print(i, type)
    
    avg_pes_list = []
    total_pes = []
    pes = []
    lens = 0
    
    for hit_list in bg_hit_list_per_event_per_type[i]:
        if len(hit_list) == 0:
            continue
        total_pes.extend(hit_list[:, -1])
        avg_pes_list.append(np.mean(hit_list[:, -1]))
        lens += len(hit_list)
    
    average_pes = np.sum(total_pes) / lens
    rate = average_pes / bg_sample_length
    
    #print(rate, "(PEs per ms)")
    print(average_pes, "average PEs per hit")
    print("Min:", np.min(total_pes), "Max:", np.max(total_pes))
    print("--------")
# Out:
# 0 Ar39GenInLAr
# 12.587768491851442 average PEs per hit
# Min: 2.5376923084259033 Max: 324.36334228515625
# --------
# 1 Kr85GenInLAr
# 14.045413049537213 average PEs per hit
# Min: 2.622307777404785 Max: 299.7761535644531
# --------
# 2 Rn222ChainGenInLAr
# 23.753370541279438 average PEs per hit
# Min: 2.630000114440918 Max: 5116.52734375
# --------
# 3 NeutronGenInRock
# 31.397099926741888 average PEs per hit
# Min: 2.9838461875915527 Max: 1751.519775390625
# --------
# 4 GammasGenInRock
# 15.375256243627462 average PEs per hit
# Min: 2.699230670928955 Max: 767.153076171875
# --------

# %%
# %matplotlib widget
fig3 = plt.figure(3)
ax3 = fig3.add_subplot(111)

#ax3.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

ax3.set_xlabel("Number of clusters per ms")
ax3.set_xscale('linear')
#ax.set_xlim(left=0.5, right=1000)

for i, type in enumerate(bg_types):
    print(i, type)
    
    total_len = 0
    lens = []
    cluster_nums = []
    for hit_list in bg_hit_list_per_event_per_type[i]:
        total_len += len(hit_list)
        lens.append(len(hit_list))
        
        candidate_clusters_2, candidate_hit_multiplicities = cl.time_clustering(hit_list, 0.2, 0.1,
                                                                                5, verbose=0)
        cluster_nums.append(len(candidate_clusters_2))
    
    average_cluster_num = np.mean(cluster_nums)
    rate = average_cluster_num / bg_sample_length
    
    print("Min:", np.min(cluster_nums) / bg_sample_length, "Max:", np.max(cluster_nums) / bg_sample_length)
    print(rate, "clusters per ms")
    
    if rate > 0.001:
        ax3.hist(np.array(cluster_nums) / bg_sample_length, bins=np.linspace(0.0001, 15, 70), label=type, density=True)
        #ax3.hist(np.array(cluster_nums) / bg_sample_length, bins=20, label=type, density=True)


box = ax.get_position()
ax3.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax3.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 0 Ar39GenInLAr
# Min: 0.0 Max: 0.23529411764705882
# 0.008823529411764706 clusters per ms
# 1 Kr85GenInLAr
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 2 Ar42GenInLAr
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 3 K42From42ArGenInLAr
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 4 Rn222ChainGenInLAr
# Min: 3.411764705882353 Max: 8.588235294117647
# 6.13 clusters per ms
# 5 K42From42ArGenInCPA
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 6 K40inGenInCPA
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 7 U238ChainGenInCPA
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 8 Co60inGenInAPA
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 9 U238ChainGenInAPA
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 10 Rn222ChainGenInPDS
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms
# 11 NeutronGenInRock
# Min: 0.0 Max: 0.35294117647058826
# 0.01392156862745098 clusters per ms
# 12 GammasGenInRock
# Min: 0.0 Max: 0.0
# 0.0 clusters per ms

# %%
((375 + 325) * 732 * 2) / (325 * 2 * 675 * 2)
w = 56
c = 112
print(w/(w+c))
c = 87869.71
w = 61989.94
print(w/(w+c))

# %%
# What about the percentage of wall hits?
show="xe"
if show == "aronly":
    bhl_per_event_per_type = bg_hit_list_per_event_per_type_ar
else:
    bhl_per_event_per_type = bg_hit_list_per_event_per_type

for i, type in enumerate(bg_types):
    print(i, type)
    
    total_len = 0
    total_wall_hits = 0
    wall_hit_fractions = []
    for hit_list in bhl_per_event_per_type[i]:
        hit_list = np.array(hit_list)
        if hit_list.shape == (0,):
            continue
        
        total_wall_hits += len(hit_list[hit_list[:,4] > -325, 0])
        total_len += len(hit_list)
        wall_hit_fractions.append(len(hit_list[hit_list[:,4] > -325, 0]) / len(hit_list))
    
    average_wall_hit_fraction = total_wall_hits / total_len

    print("Wall hit fraction (average)", average_wall_hit_fraction)
    print("Min:", np.min(wall_hit_fractions), "Max:", np.max(wall_hit_fractions))
# Out:
# 0 Ar39GenInLAr
# Wall hit fraction (average) 0.3835874724265227
# Min: 0.34516680923866555 Max: 0.4222776392352452
# 1 Kr85GenInLAr
# Wall hit fraction (average) 0.38333456373361613
# Min: 0.29118773946360155 Max: 0.4817813765182186
# 2 Ar42GenInLAr
# Wall hit fraction (average) 0.36645962732919257
# Min: 0.0 Max: 1.0
# 3 K42From42ArGenInLAr
# Wall hit fraction (average) 0.224
# Min: 0.0 Max: 1.0
# 4 Rn222ChainGenInLAr
# Wall hit fraction (average) 0.36057785043685037
# Min: 0.27351247600767753 Max: 0.448207171314741
# 5 K42From42ArGenInCPA
# Wall hit fraction (average) 0.029221882432891606
# Min: 0.0 Max: 0.5
# 6 K40inGenInCPA
# Wall hit fraction (average) 0.021052631578947368
# Min: 0.0 Max: 0.5
# 7 U238ChainGenInCPA
# Wall hit fraction (average) 0.02804878048780488
# Min: 0.0 Max: 1.0
# 8 Co60inGenInAPA
# Wall hit fraction (average) 0.6521739130434783
# Min: 0.0 Max: 1.0
# 9 U238ChainGenInAPA
# Wall hit fraction (average) 0.7820989419502431
# Min: 0.0 Max: 1.0
# 10 Rn222ChainGenInPDS
# Wall hit fraction (average) 0.41825095057034223
# Min: 0.0 Max: 1.0
# 11 NeutronGenInRock
# Wall hit fraction (average) 0.45129224652087474
# Min: 0.0 Max: 1.0
# 12 GammasGenInRock
# Wall hit fraction (average) 0.7990438081380242
# Min: 0.6206896551724138 Max: 0.8918918918918919

# %% [markdown]
# # Now for supernova stats

# %%
import importlib
import parameters
importlib.reload(parameters)
from parameters import *
importlib.reload(sl)

sim_mode = "xe"
adc_mode = "normal"
sn_data_dir = "/eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/"
#sn_data_dir = "/eos/project-e/ep-nu/pbarhama/sn_saves/new_photon_lib_prod_snnue_pds/"

sn_limit = 100
sn_total_hits, sn_hit_list_per_event, sn_info_per_event, _ = sl.load_all_sn_events_chunky(limit=sn_limit, event_num=1000,
                                                                                          detector="VD", sim_mode=sim_mode, adc_mode=adc_mode, offset=1,
                                                                                             sn_data_dir=sn_data_dir)
#sn_total_hits_ar, sn_hit_list_per_event_ar, sn_info_per_event_ar, _ = sl.load_all_sn_events_chunky(limit=sn_limit, event_num=1000, 
#                                                                                          detector="VD", sim_mode="aronly", adc_mode=adc_mode, offset=1)
print("d")
# Out:
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.168452050_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066151.391133857_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.974487932_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.607917696_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.882381591_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066155.036448240_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.059945005_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.577804544_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066160.467672833_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.075636833_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.550531198_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.049568591_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.317856474_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.255585800_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.939634558_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.612903662_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.577804544_stana_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.049568591_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066155.036448240_stana_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066160.467672833_stana_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.168452050_stana_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.255585800_stana_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.612903662_stana_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.882381591_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.974487932_stana_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.550531198_stana_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066151.391133857_stana_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.317856474_stana_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.607917696_stana_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.939634558_stana_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.075636833_stana_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.059945005_stana_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.678028706_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.985045959_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.154948237_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.615886916_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066163.570972813_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.853637965_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066161.465272731_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.317738184_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066155.495153706_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.641695957_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066158.968258677_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.533326065_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.327658145_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066151.875031675_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.240803263_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.700725450_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.678028706_stana_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.615886916_stana_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.154948237_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.985045959_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.317738184_stana_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066163.570972813_stana_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.853637965_stana_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066161.465272731_stana_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066151.875031675_stana_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066155.495153706_stana_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.641695957_stana_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066158.968258677_stana_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.700725450_stana_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.327658145_stana_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.533326065_stana_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.240803263_stana_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.671816766_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066165.728659574_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066166.867858608_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.451178387_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.709480105_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066168.692258147_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066169.334541886_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.671816766_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066165.728659574_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066169.785977539_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066170.399011348_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066166.867858608_stana_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066172.266400364_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.002776022_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.709480105_stana_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.451178387_stana_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.685832851_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066168.692258147_stana_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066165.367605870_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066166.435137459_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.740792312_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066169.334541886_stana_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066169.785977539_stana_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.891715407_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.975329474_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066170.399011348_stana_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066166.907838078_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066172.266400364_stana_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.083057565_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.002776022_stana_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.685832851_stana_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.695401045_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066168.562993754_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.740792312_stana_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066168.885237521_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066166.435137459_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066170.178191285_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066165.367605870_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066169.534732627_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066172.187248171_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.891715407_stana_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.975329474_stana_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.083057565_stana_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066166.907838078_stana_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.136936287_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066172.978531194_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.695401045_stana_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066168.562993754_stana_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.688253385_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.869713091_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066170.178191285_stana_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066168.885237521_stana_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066169.534732627_stana_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066172.187248171_stana_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.919473559_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.988680581_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.660964096_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.557486194_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.136936287_stana_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066175.043674807_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066172.978531194_stana_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.688253385_stana_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066176.925477890_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.869713091_stana_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.694073470_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.919473559_stana_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066178.903198950_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.660964096_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.181896742_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066175.043674807_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.988680581_stana_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.557486194_stana_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.888789274_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.200456331_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066176.925477890_stana_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.694073470_stana_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.075019844_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.911196718_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066178.903198950_stana_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.947773806_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066183.867462949_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066175.194293440_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.181896742_stana_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.173459050_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.888789274_stana_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.947773806_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.259559229_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.200456331_stana_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.077574851_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.444268513_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.075019844_stana_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066178.871684291_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.494029345_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.911196718_stana_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.738041701_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066183.867462949_stana_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.177578612_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066175.194293440_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.173459050_stana_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.644722699_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.184032545_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.259559229_stana_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.077574851_stana_hist.root <ForkProcess name='ForkPoolWorker-64' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.571543644_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.462377939_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.539908931_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066183.420939571_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.494029345_stana_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.444268513_stana_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066178.871684291_stana_hist.root <ForkProcess name='ForkPoolWorker-62' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.177578612_stana_hist.root <ForkProcess name='ForkPoolWorker-55' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.738041701_stana_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.104511840_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.232798891_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.379466727_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066179.644722699_stana_hist.root <ForkProcess name='ForkPoolWorker-58' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.184032545_stana_hist.root <ForkProcess name='ForkPoolWorker-50' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.264985050_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.571543644_stana_hist.root <ForkProcess name='ForkPoolWorker-49' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066183.420939571_stana_hist.root <ForkProcess name='ForkPoolWorker-51' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.539908931_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.462377939_stana_hist.root <ForkProcess name='ForkPoolWorker-57' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.453595595_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.623462548_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.232798891_stana_hist.root <ForkProcess name='ForkPoolWorker-59' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.379466727_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.104511840_stana_hist.root <ForkProcess name='ForkPoolWorker-52' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.388592917_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.264985050_stana_hist.root <ForkProcess name='ForkPoolWorker-53' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.453595595_stana_hist.root <ForkProcess name='ForkPoolWorker-61' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.790131266_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.623462548_stana_hist.root <ForkProcess name='ForkPoolWorker-60' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.466678032_g4_detsim_xe_reco_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.388592917_stana_hist.root <ForkProcess name='ForkPoolWorker-54' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.790131266_stana_hist.root <ForkProcess name='ForkPoolWorker-56' parent=512 started daemon>
# /eos/project-e/ep-nu/pbarhama/sn_saves/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.466678032_stana_hist.root <ForkProcess name='ForkPoolWorker-63' parent=512 started daemon>
# d

# %%
print(len(sn_hit_list_per_event), sn_info_per_event.shape)

total_len = 0
total_wall_hits = 0
wall_hit_fractions = []
for hit_list in sn_hit_list_per_event:
    hit_list = np.array(hit_list)
    if hit_list.shape == (0,):
        continue
        
    total_wall_hits += len(hit_list[hit_list[:,4] > -325, 0])
    total_len += len(hit_list)
    
    wall_hit_fractions.append(len(hit_list[hit_list[:,4] > -325, 0]) / len(hit_list))
    
average_wall_hit_fraction = total_wall_hits / total_len

print("Wall hit fraction (average)", average_wall_hit_fraction)
print("Min:", np.min(wall_hit_fractions), "Max:", np.max(wall_hit_fractions))
# Out:
# 100000 (100000, 4)
# Wall hit fraction (average) 0.40514052798042377
# Min: 0.0 Max: 1.0

# %%
# %matplotlib widget
plt.figure(320)
print(np.array(sn_info_per_event[:, 0]))
plt.hist(sn_info_per_event[:, 0], bins=50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [38.042423 63.652233 91.34073  ... 44.533207 58.274544 34.718487]

# %%
print(sn_info_per_event[:, 2])

#outside = np.where((np.abs(sn_info_per_event[:, 2]) > 675) & (np.abs(sn_info_per_event[:, 1] > 325)))[0]
outside = np.where(np.abs(sn_info_per_event[:, 2]) > 675)[0]

#outside = np.where((np.abs(sn_info_per_event[:, 2]) > 600) & (np.abs(sn_info_per_event[:, 2]) < 675) & (sn_info_per_event[:, 1] > 50) & (sn_info_per_event[:, 1] < 250))[0]

hlens = []
for i, hl in enumerate(sn_hit_list_per_event):
    if i in outside:
        continue
    hlens.append(len(hl))
print("Avg:", np.mean(hlens), "Max:", np.max(hlens), "Min:", np.min(hlens))

plt.figure(1234)
plt.hist(sn_info_per_event[outside, 2], bins=50)
plt.show()
# Out:
# [-698.16205 -626.4855  -362.5132  ...  328.26364  238.6372  -161.80247]
# Avg: 21.012533339115727 Max: 64 Min: 0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## PE's per MeV (Per Event) RESTRICTED

# %%
# PE's per MeV (PER EVENT)
# %matplotlib widget

min_e = 5
max_e = 30

# Fraction of hitless/low hit events
hit_lim = 1
low_hit = 0
total_hit = 0

plt.figure(12)
pes = []
pe_per_mev = []
energies = []
print(len(sn_hit_list_per_event), sn_info_per_event.shape)
for i, elist in enumerate(sn_hit_list_per_event):
    
    # Only wall arapucas
    if elist.shape != (0,):
        elist = elist[elist[:,5] > 0]
    
    # Only within geometry limits (see above cell)
    if i not in outside:
        #print("not outside")
         continue
    
    # Only within energy limits
    energy = (sn_info_per_event[i, 0])
    if energy < min_e:
        continue
    if energy > max_e:
        continue
    
    # Low hit event?
    total_hit += 1
    if len(elist) < hit_lim:
        low_hit += 1
    
    if elist.shape == (0,):
        pe = 0
    else:
        pe = np.sum(elist[:, -1])
    
    energies.append(energy)
    pes.append(pe)
    pe_per_mev.append(pe/energy)

# Fraction of low hit events
print("Fraction of low hit events", low_hit/total_hit)
#print(low_hit, total_hit)

pes = np.array(pes)
plt.scatter(energies, pes, s=2)

#plt.ylim(top=20, bottom=-1)

plt.xlabel("MeV")
plt.ylabel("PE")

print(np.mean(pe_per_mev))

coef = np.polyfit(energies, pes, 1)
poly1d_fn = np.poly1d(coef) 
#plt.plot(energies, poly1d_fn(energies), c='black', linewidth=2)
print(coef)

plt.figure()
h, bins, _ = plt.hist(energies, bins=np.arange(min_e, max_e + 1, 1))
h2, bins2, _ = plt.hist(energies, bins=np.arange(min_e, max_e + 1, 1), weights=pes)

me = []
ct = []
for i in range(len(h)):
    me.append((bins[i] + bins[i+1])/2)
    ct.append(h2[i]/h[i])

plt.figure()
plt.bar(bins[:-1], np.array(ct)/np.array(me))
plt.xlabel("MeV")
plt.ylabel("PE/MeV")
#plt.ylim(0, 26)

# %% [markdown]
# ## PE's per MeV (Per Event) ALL EVENTS

# %%
# PE's per MeV (PER EVENT)
# %matplotlib widget

# For the histogram = 0 to be white
from matplotlib.colors import ListedColormap
import matplotlib as mpl
original_cmap = plt.cm.plasma
colors = original_cmap(np.arange(original_cmap.N))
colors[0, :] = np.array([1, 1, 1, 1])
custom_cmap = ListedColormap(colors)

min_e = 5
max_e = 30

# Fraction of hitless/low hit events
hit_lim = 1
low_hit = 0
total_hit = 0

plt.figure(12)
pes = []
pe_per_mev = []
energies = []
print(len(sn_hit_list_per_event), sn_info_per_event.shape)
for i, elist in enumerate(sn_hit_list_per_event):
    
    # Only within energy limits
    energy = (sn_info_per_event[i, 0])
    if energy < min_e:
        continue
    if energy > max_e:
        continue
    
    # Low hit event?
    total_hit += 1
    if len(elist) < hit_lim:
        low_hit += 1
    
    if elist.shape == (0,):
        pe = 0
    else:
        pe = np.sum(elist[:, -1])
    
    energies.append(energy)
    pes.append(pe)
    pe_per_mev.append(pe/energy)

# Fraction of low hit events
print("Fraction of low hit events", low_hit/total_hit)
#print(low_hit, total_hit)

pes = np.array(pes)
plt.scatter(energies, pes, s=1)
plt.xlabel("MeV")
plt.ylabel("PE")
plt.ylim(top=5000)

plt.figure()
plt.hist2d(energies, pes, bins=(80,80), norm=mpl.colors.LogNorm(), cmap=custom_cmap)
plt.colorbar()
plt.ylim(top=5000)

plt.xlabel("MeV")
plt.ylabel("PE")

print(np.mean(pe_per_mev))

X = np.array(energies).reshape(-1, 1)
coef, _, _, _ = np.linalg.lstsq(X, pes, rcond=None)

#coef = np.polyfit(energies, pes, 1)
#poly1d_fn = np.poly1d(coef) 
plt.plot(energies, energies*coef, c='black', linewidth=2)
print(coef)

plt.figure()
h, bins, _ = plt.hist(energies, bins=np.arange(min_e, max_e + 1, 1))
h2, bins2, _ = plt.hist(energies, bins=np.arange(min_e, max_e + 1, 1), weights=pes)

me = []
ct = []
for i in range(len(h)):
    me.append((bins[i] + bins[i+1])/2)
    ct.append(h2[i]/h[i])

plt.figure()
plt.bar(bins[:-1], np.array(ct)/np.array(me))
plt.xlabel("MeV")
plt.ylabel("PE/MeV")
plt.ylim(0, 26)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 100000 (100000, 4)
# Fraction of low hit events 0.12616426756985605
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 17.34831145214301
# [18.75111401]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (0.0, 26.0)

# %% [markdown]
# ## PE's Per MeV (PER HIT)

# %%
# Now we will look at the average PE PER HIT
# %matplotlib widget

min_e = 5
max_e = 100

plt.figure(12)
pes = []
pes_per_mev = []
energies = []

print(len(sn_hit_list_per_event), sn_info_per_event.shape)
for i, elist in enumerate(sn_hit_list_per_event):
    energy = (sn_info_per_event[i, 0])
    if energy < min_e:
        continue
    if energy > max_e:
        continue
    
    if elist.shape == (0,):
        continue
        
    energies.extend([energy] * len(elist[:, -1]))
    
    pes.extend(elist[:, -1])
    pes_per_mev.extend(elist[:, -1]/np.array(energy))

pes = np.array(pes)
plt.scatter(energies, pes, s=2)
plt.ylim(top=1000, bottom=2)
plt.ylabel("PE")
plt.xlabel("MeV")

print("PE/MeV per hit - mean:", np.mean(pes_per_mev))
print("MAX/MIN:", np.max(pes), np.min(pes))

coef = np.polyfit(energies, pes, 1)
poly1d_fn = np.poly1d(coef) 
plt.plot(energies, poly1d_fn(energies), c='black', linewidth=2)
print("LINEAR FIT:", coef)

plt.figure()
h, bins, _ = plt.hist(energies, bins=np.arange(min_e, max_e + 1, 1))
h2, bins2, _ = plt.hist(energies, bins=np.arange(min_e, max_e + 1, 1), weights=pes)

me = []
ct = []
for i in range(len(h)):
    me.append((bins[i] + bins[i+1])/2)
    ct.append(h2[i]/h[i])

plt.figure()
plt.bar(bins[:-1], np.array(ct)/np.array(me))
plt.xlabel("MeV")
plt.ylabel("PE/MeV")
#plt.ylim(0, 26)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 100000 (100000, 4)
# PE/MeV per hit - mean: 1.0524839919407207
# MAX/MIN: 7898.78369140625 2.6761538982391357
# /cvmfs/sft.cern.ch/lcg/views/LCG_100/x86_64-centos7-gcc8-opt/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3296: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# LINEAR FIT: [ 0.44679727 30.58682959]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0, 0.5, 'PE/MeV')

# %%
aux.distance_to_event_number(125, model="GARCHING")

# %%
# %matplotlib widget

hit_lim = 10

plt.figure(120)
hit_nums = []
high_nums = []

hit_num_per_mev = []
energies = []
h_energies = []
for i, elist in enumerate(sn_hit_list_per_event):
    energy = sn_info_per_event[i, 0]
    hit_num = len(elist)
    
    if hit_num >= hit_lim:
        high_nums.append(hit_num)
        h_energies.append(energy)
    
    energies.append(energy)

    hit_nums.append(hit_num)
    hit_num_per_mev.append(hit_num/energy)

plt.scatter(energies, hit_nums, s=2)
plt.xlabel('MeV')
plt.ylabel('Number of hits')

#plt.ylim(0, 10)
plt.xlim(5, 30)
plt.ylim(-1, 60)

plt.figure(20)
n, b, _ = plt.hist(energies, bins=np.arange(4, 31, 1))
nh, _, _ = plt.hist(h_energies, bins=np.arange(4, 31, 1))

plt.figure(30)
plt.plot(b[:-1], nh/n)
plt.xlabel('MeV')
plt.title('Fraction of events with >= {} hits'.format(hit_lim))

# Percentage of hitless

# %%
# Number of events vs true X (as requested by Laura)
#true_x = sn_info_per_event[:, 1]

hit_lim = 1

plt.figure(190)
hit_nums = []
high_nums = []

hit_num_per_cm = []
xs = []
h_xs = []
for i, elist in enumerate(sn_hit_list_per_event):
    x = sn_info_per_event[i, 1]
    energy = sn_info_per_event[i, 0]
    
    # We are only interested in a certain energy range
    if energy > 30:
        continue
    
    hit_num = len(elist)
    
    if hit_num >= hit_lim:
        high_nums.append(hit_num)
        h_xs.append(x)
    
    xs.append(x)

    hit_nums.append(hit_num)
    hit_num_per_cm.append(hit_num/x)

plt.scatter(xs, hit_nums, s=2)
plt.xlabel("x (cm)")
plt.ylabel('Hit number')

#plt.ylim(0, 10)

plt.figure(200)
n, b, _ = plt.hist(xs, bins=100)
nh, _, _ = plt.hist(h_xs, bins=100)

plt.figure(300)
plt.plot(b[:-1], nh/n)
plt.xlabel('x (cm)')
plt.title('Fraction of events with >= {} hits'.format(hit_lim))

# %% [markdown]
# ## 2D light maps

# %%
# PE's per MeV (PER EVENT)
# %matplotlib widget

min_e = 5
max_e = 30

# Fraction of hitless/low hit events
hit_lim = 1
low_hit = 0
total_hit = 0

pes = []
pe_per_mev = []
energies = []

xs = []
ys = []
zs = []

# Cut in z?
min_z = 0
max_z = 2100

print(len(sn_hit_list_per_event), sn_info_per_event.shape)

for i, elist in enumerate(sn_hit_list_per_event):
    x = sn_info_per_event[i, 1]
    y = sn_info_per_event[i, 2]
    z = sn_info_per_event[i, 3]
    
    # Only within energy limits
    energy = sn_info_per_event[i, 0]
    if energy < min_e:
        continue
    if energy > max_e:
        continue
        
    # Only within z limits
    if z < min_z:
        continue
    if z > max_z:
        continue
        
    # Low hit event?
    total_hit += 1
    if len(elist) < hit_lim:
        low_hit += 1
    
    if elist.shape == (0,):
        pe = 0
    else:
        pe = np.sum(elist[:, -1])
    
    energies.append(energy)
    pes.append(pe)
    pe_per_mev.append(pe/energy)
    
    xs.append(x)
    ys.append(y)
    zs.append(z)

# Average LY for the sample collected
print("AVERAGE LY:", np.mean(pe_per_mev))
    
    
# Get the number of values in each bin
bins_x = np.concatenate((np.array([-732]), np.linspace(-675, 675, num=13),np.array([732])))
bins_y = np.linspace(-327, 375, num=13)

plt.figure(30)
hist, _, _, _ = plt.hist2d(ys, xs, bins=(bins_x, bins_y))
plt.colorbar()

# Get the histogram weighted by pes_per_mev
plt.figure(40)
hist_w, xedges, yedges, _ = plt.hist2d(ys, xs, bins=(bins_x, bins_y), weights=pe_per_mev)
plt.colorbar()

# Divide by the number of values in each bin to get the average
light_map = hist_w/hist
fig, ax = plt.subplots()
cax = ax.pcolormesh(xedges, yedges, light_map.T, cmap='inferno', vmin=0, vmax=83)
fig.colorbar(cax, label='PE/MeV')

ax.set_xlabel("y (cm)")
ax.set_ylabel("x (cm)")
# Out:
# 100000 (100000, 4)
# AVERAGE LY: 19.150456265269447
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0, 0.5, 'x (cm)')

# %% [markdown]
# ## Time distribution for arriving photons (?)

# %%
# %matplotlib widget

min_e = 5
max_e = 30

energies = []
pes = []
pe_per_mev = []
all_peak_times = []

for i, elist in enumerate(sn_hit_list_per_event):
    
    # Only within energy limits
    energy = (sn_info_per_event[i, 0])
    if energy < min_e:
        continue
    if energy > max_e:
        continue
    
    if elist.shape == (0,):
        continue
    
    peak_times = elist[:, 3]
    all_peak_times.extend(peak_times)
    
    if elist.shape == (0,):
        pe = 0
    else:
        pe = np.sum(elist[:, -1])
    
    energies.append(energy)
    pes.append(pe)
    pe_per_mev.append(pe/energy)

plt.figure()
#bins = np.linspace(-5, 3000, 200)
bins = np.linspace(-5, 50, 200)
plt.hist(all_peak_times, bins=bins)
#plt.ylim(top=2e5, bottom=4e-1)
plt.yscale('log')
plt.xlabel("time (mu s)")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 0, 'time (mu s)')

# %% [markdown]
# ## Checks for the GNN. See if the SN hits make sense

# %%
# sn_hit_list_per_event, sn_info_per_event

pes 

for i, hl in enumerate(sn_hit_list_per_event):
