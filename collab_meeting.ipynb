# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
import scipy.stats as stats

from parameters import *

import save_n_load as sl
import clustering as cl
import hit_stat as hs
import aux

# %%
X_COORDS, Y_COORDS, Z_COORDS = laura_load_coordinate_arrays() if GEOMETRY_VERSION == "v4" else v5_load_coordinate_arrays(detector=DETECTOR)

print(len(X_COORDS[X_COORDS < 0]))
# Out:
# 112

# %% [markdown]
# ## Load SN events

# %%
detector = "VD"

if detector == "VD":
    sn_data_dir = EVENT_DATA_DIR
    sim_mode = "xe"
elif detector == "HD":
    sn_data_dir = ""
    sim_mode = "aronly"

sn_total_hits, sn_hit_list_per_event, sn_info_per_event, _ = sl.load_all_sn_events_chunky(limit=100, event_num=1000, detector=detector, sn_data_dir=sn_data_dir,
                                                                                          sim_mode=sim_mode)

print(len(sn_hit_list_per_event), len(sn_info_per_event))
# Out:
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066176.925477890_g4_detsim_xe_reco_hist.root /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066276.946967443_g4_detsim_xe_reco_hist.root /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066209.652201085_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.264985050_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.451178387_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066148.336856460_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066161.465272731_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066218.656196856_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066209.342432064_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066215.174997458_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066209.342432064_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.451178387_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066148.336856460_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066161.465272731_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066276.946967443_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066176.925477890_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066209.652201085_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066218.656196856_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066215.174997458_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.264985050_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.891715407_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.985045959_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.891128522_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.168452050_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.539908931_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.770351194_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.317856474_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.607917696_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066226.199055965_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.571543644_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.985045959_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.891715407_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066186.539908931_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.891128522_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.770351194_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066154.607917696_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.317856474_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.168452050_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.571543644_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066226.199055965_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066244.247378381_g4_detsim_xe_reco_hist.root /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066151.875031675_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.083057565_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066219.948503668_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066212.481773181_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.961389895_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.738041701_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066222.914939686_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.615886916_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.445180793_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066219.948503668_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.961389895_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066151.875031675_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066174.083057565_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066244.247378381_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066222.914939686_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066212.481773181_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.615886916_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.738041701_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.445180793_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066224.208772896_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066224.208772896_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066226.013099617_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066212.119259180_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066214.233267844_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066226.013099617_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066212.119259180_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066170.399011348_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066214.233267844_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066212.421593349_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.136936287_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.184032545_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066170.399011348_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.030426437_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066212.421593349_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.136936287_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066220.590168404_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.184032545_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066230.053546813_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.030426437_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.028119095_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066220.590168404_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.694073470_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066204.686763712_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066230.053546813_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.466678032_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.028119095_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066217.430758858_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.259559229_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.694073470_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066228.004721316_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066204.686763712_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066187.466678032_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066217.430758858_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.259559229_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066189.797059576_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066227.879820062_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066228.004721316_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.641695957_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.911196718_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066221.894092969_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066189.797059576_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066227.879820062_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.641695957_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.911196718_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066220.409184586_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066206.290071491_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066221.894092969_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.394750131_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.240803263_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066202.691895684_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066206.290071491_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066220.409184586_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.695401045_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.240803263_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.394750131_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066219.633878984_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066202.691895684_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.612903662_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.075019844_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.444268513_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066167.695401045_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066219.633878984_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066175.194293440_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066242.097788354_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066162.612903662_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066182.075019844_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066185.444268513_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066193.355536113_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.200456331_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066175.194293440_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066242.097788354_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.059945005_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.075636833_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066193.355536113_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066181.200456331_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066197.586703030_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.255585800_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066221.017683578_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066156.059945005_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.075636833_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066215.429070307_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066201.975980141_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066188.102026890_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066197.586703030_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066221.017683578_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066164.255585800_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066219.061271513_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066215.429070307_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.195976255_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066201.975980141_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066218.085925274_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066188.102026890_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066246.691865905_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066219.061271513_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066213.195976255_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.291757240_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066218.085925274_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066190.859797871_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066205.478560181_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066207.651333814_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066246.691865905_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.291757240_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066190.859797871_stana_hist.root <SpawnProcess name='SpawnPoolWorker-23' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066189.961558662_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066205.478560181_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066207.651333814_stana_hist.root <SpawnProcess name='SpawnPoolWorker-30' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.327658145_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066214.834986061_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066189.961558662_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066178.903198950_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.988680581_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.987237610_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066214.834986061_stana_hist.root <SpawnProcess name='SpawnPoolWorker-29' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066157.327658145_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066218.723216364_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066178.903198950_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066173.988680581_stana_hist.root <SpawnProcess name='SpawnPoolWorker-28' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066223.987237610_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066216.533453822_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066206.642357345_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066218.723216364_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066194.248985409_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066183.420939571_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066216.533453822_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066206.642357345_stana_hist.root <SpawnProcess name='SpawnPoolWorker-24' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066224.089956868_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066165.728659574_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066194.248985409_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.853637965_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066183.420939571_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066224.089956868_stana_hist.root <SpawnProcess name='SpawnPoolWorker-21' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066215.995727213_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066165.728659574_stana_hist.root <SpawnProcess name='SpawnPoolWorker-25' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.077574851_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066153.853637965_stana_hist.root <SpawnProcess name='SpawnPoolWorker-22' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066215.995727213_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066177.077574851_stana_hist.root <SpawnProcess name='SpawnPoolWorker-27' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066163.570972813_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_snnue_pds/prodmarley_nue_dune10kt_vd_1x8x14_larger_1682066163.570972813_stana_hist.root <SpawnProcess name='SpawnPoolWorker-26' parent=97521 started daemon>
# 100000 100000

# %% [markdown]
# ## Load the BG

# %%
detector = "VD"
X_COORDS, Y_COORDS, Z_COORDS = laura_load_coordinate_arrays() if GEOMETRY_VERSION == "v4" else v5_load_coordinate_arrays(detector=detector)
bg_limit = 10

if detector == "VD":
    bg_types = ["Ar39GenInLAr", "Kr85GenInLAr", "Rn222ChainGenInLAr", "NeutronGenInRock", "Ar42GenInLAr", "K42From42ArGenInLAr", "U238ChainGenInCPA",
                "U238ChainGenInAPA", "Rn222ChainGenInPDS", "GammasGenInRock"]
    bg_data_dir = BG_DATA_DIR
    sim_mode = "xe"

    bg_sample_length = 8.5 # ms
    num_channels = 184
    num_arapucas = 184
    size_arapucas = 60 * 60 # cm ^ 2

    # Total number of arapucas: 672, of which in cathode: 320 (double rate)
    # In v5 geometry: 184, 112 in cathode (double rate)
    wall_rate_mult = (672 - 320) / (184 - 112)
    cathode_rate_mult = 320 / 112
    cathode_num_channels = 112
    wall_num_channels = 72

elif detector == "HD":
    bg_types = [
        "Ar39GenInLAr", "Kr85GenInLAr", "Ar42GenInLAr", "K42From42ArGenInLAr",
        "Rn222ChainRn222GenInLAr", "Rn222ChainPo218GenInLAr", "Rn222ChainPb214GenInLAr",
        "Rn222ChainBi214GenInLAr", "Rn222ChainPb210GenInLAr", "Rn220ChainPb212GenInLAr",
        "K40GenInCPA", "U238ChainGenInCPA", "K42From42ArGenInCPA",
        "Rn222ChainPo218GenInCPA", "Rn222ChainPb214GenInCPA", "Rn222ChainBi214GenInCPA",
        "Rn222ChainPb210GenInCPA", "Rn222ChainFromBi210GenInCPA", "Rn220ChainFromPb212GenInCPA",
        "Co60GenInAPA", "U238ChainGenInAPA", "Th232ChainGenInAPA",
        "Rn222ChainGenInPDS", "CavernwallGammasAtLAr", "foamGammasAtLAr",
        "CavernwallNeutronsAtLAr", "CryostatNGammasAtLAr", "CavernNGammasAtLAr"
    ]

    bg_data_dir = "/Users/pbarham/OneDrive/workspace/cern/ruth/v3_hd_background/"
    sim_mode = "aronly"

    bg_sample_length = 4.492 # ms
    num_channels = 480
    num_arapucas = 480 // 4
    size_arapucas = 50 * 10 # cm ^ 2

    # 1000 arapucas on the cathode, with 4 channels each
    total_rate_mult = (500 * 4 + 1000/2 * 4) / num_channels


bg_total_hits, bg_hit_list_per_event, _, bg_total_hits_per_type, bg_hit_list_per_event_per_type =\
                                    sl.load_all_backgrounds_chunky_type_separated(limit=bg_limit, detector=detector, adc_mode="normal",
                                            sim_mode=sim_mode, offset=0, bg_types=bg_types, bg_data_dir=bg_data_dir);
# Out:
# prodbg_radiological_dune10kt_vd_1x8x14_1686581866.845132282_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686599784.582491595_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686601409.274761323_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582100.156543123_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582106.064575825_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581864.403750629_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582569.551480772_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686673380.707449524_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686621966.289441943_Ar39GenInLAr_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582569.551480772_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-38' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582106.064575825_Ar39GenInLAr_g4_detsim_xe_reco_hist.root/Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686581866.845132282_Ar39GenInLAr_g4_detsim_xe_reco_hist.root  <SpawnProcess name='SpawnPoolWorker-36' parent=97521 started daemon>
# <SpawnProcess name='SpawnPoolWorker-31' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005061.263001319_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-32' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582100.156543123_Ar39GenInLAr_g4_detsim_xe_reco_hist.root/Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686601409.274761323_Ar39GenInLAr_g4_detsim_xe_reco_hist.root  <SpawnProcess name='SpawnPoolWorker-34' parent=97521 started daemon>
# <SpawnProcess name='SpawnPoolWorker-35' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686581864.403750629_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-37' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686599784.582491595_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-33' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686673380.707449524_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-39' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar39GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686621966.289441943_Ar39GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-40' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686582458.485435563_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686676461.680773645_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582569.363060628_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005213.864899908_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005077.632977098_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649626.593389054_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686674983.951338044_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686599383.242583835_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582107.133706406_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649655.979667978_Kr85GenInLAr_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686674983.951338044_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-47' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686676461.680773645_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-42' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582458.485435563_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-41' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582107.133706406_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-49' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005077.632977098_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-45' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582569.363060628_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-43' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686599383.242583835_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-48' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686649626.593389054_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-46' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005213.864899908_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-44' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Kr85GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686649655.979667978_Kr85GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-50' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686610791.219769446_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649633.233820446_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686620485.026531037_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686673180.133276875_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686617226.874843682_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005077.747773503_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686596513.109458804_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686671919.278961150_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649658.731287968_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005077.747773503_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-56' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686617226.874843682_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-55' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686671919.278961150_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-58' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686673180.133276875_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-54' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686620485.026531037_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-53' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686596513.109458804_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-57' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686649633.233820446_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-52' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686610791.219769446_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-51' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686649658.731287968_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-60' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005059.056901917_Rn222ChainGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-59' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686617842.983842213_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686617695.640161410_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005110.913317677_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686597473.844759408_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582104.019223899_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649648.375340003_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649665.490183742_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649621.398219587_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686686447.950731875_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686674080.535584201_NeutronGenInRock_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686617695.640161410_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-62' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686582104.019223899_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-65' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005110.913317677_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-63' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686617842.983842213_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-61' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686597473.844759408_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-64' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686649648.375340003_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-66' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686649621.398219587_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-68' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686686447.950731875_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-69' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686649665.490183742_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-67' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/NeutronGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686674080.535584201_NeutronGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-70' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686581761.852967931_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581866.943214180_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686607252.542331158_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686678708.596709746_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582102.847994555_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581761.014285603_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005098.653414815_Ar42GenInLAr_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686607252.542331158_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-73' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005062.005144612_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-75' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686582102.847994555_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-76' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005055.203798150_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-78' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005058.627715043_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-79' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686581866.943214180_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-72' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686678708.596709746_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-74' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686581761.014285603_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-77' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686581761.852967931_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-71' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Ar42GenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005098.653414815_Ar42GenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-80' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1682005071.399955621_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686599791.220841189_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686601199.077066140_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649604.995108305_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649605.456831243_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686606286.487435474_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686614849.797518915_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686615006.237972691_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005092.759149290_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686621417.212488372_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686649604.995108305_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-84' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686606286.487435474_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-86' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005071.399955621_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-81' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686601199.077066140_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-83' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686649605.456831243_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-85' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686599791.220841189_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-82' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686614849.797518915_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-87' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1682005092.759149290_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-89' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686615006.237972691_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-88' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/K42From42ArGenInLAr/prodbg_radiological_dune10kt_vd_1x8x14_1686621417.212488372_K42From42ArGenInLAr_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-90' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686649657.376231279_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686621129.044706195_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686616165.642344216_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686674983.949538713_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581868.930987179_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686597838.548443373_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582460.499249154_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686582978.412184431_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686599848.258314398_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686597838.548443373_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-97' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686621129.044706195_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-92' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686616165.642344216_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-93' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686581868.930987179_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-96' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1682005063.533008725_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-95' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686649657.376231279_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-91' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686674983.949538713_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-94' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686582460.499249154_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-98' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686582978.412184431_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-99' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInCPA/prodbg_radiological_dune10kt_vd_1x8x14_1686599848.258314398_U238ChainGenInCPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-100' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686582100.417467453_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649645.864725395_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686601411.365334739_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581769.977595383_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005067.826681486_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005070.658772716_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581868.189680913_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686673833.711453244_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686604972.267955587_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686600575.284140633_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686649645.864725395_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-102' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1682005067.826681486_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-105' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686582100.417467453_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-101' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686601411.365334739_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-103' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1682005070.658772716_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-106' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686581868.189680913_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-107' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686581769.977595383_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-104' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686600575.284140633_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-110' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686673833.711453244_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-108' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/U238ChainGenInAPA/prodbg_radiological_dune10kt_vd_1x8x14_1686604972.267955587_U238ChainGenInAPA_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-109' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686649610.688833590_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686611598.572703490_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686600856.180764368_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686607182.211022695_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686599446.029707294_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686604598.117824816_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649645.864725395_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686673833.711453244_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649604.032375868_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581864.402660990_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686611598.572703490_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-112' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686604598.117824816_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-116' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686600856.180764368_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-113' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686599446.029707294_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-115' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686649610.688833590_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-111' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686673833.711453244_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-118' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686649645.864725395_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-117' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686581864.402660990_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-120' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686649604.032375868_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-119' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/Rn222ChainGenInPDS/prodbg_radiological_dune10kt_vd_1x8x14_1686607182.211022695_Rn222ChainGenInPDS_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-114' parent=97521 started daemon>
# prodbg_radiological_dune10kt_vd_1x8x14_1686599446.029707294_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686610786.043076832_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649614.778146732_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686600857.873587509_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686581768.749688824_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686606286.487464330_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686685761.350321023_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686674155.348908885_GammasGenInRock_g4_detsim_xe_reco_hist.root
# prodbg_radiological_dune10kt_vd_1x8x14_1686649650.949391977_GammasGenInRock_g4_detsim_xe_reco_hist.root
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686610786.043076832_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-122' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686581768.749688824_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-125' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1682005057.339652280_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-126' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686649614.778146732_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-123' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686606286.487464330_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-127' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686599446.029707294_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-121' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686685761.350321023_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-128' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686600857.873587509_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-124' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686649650.949391977_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-130' parent=97521 started daemon>
# /Users/pbarham/OneDrive/workspace/cern/ruth/new_compgraph_prod_background_pds/GammasGenInRock/prodbg_radiological_dune10kt_vd_1x8x14_1686674155.348908885_GammasGenInRock_g4_detsim_xe_reco_hist.root <SpawnProcess name='SpawnPoolWorker-129' parent=97521 started daemon>

# %% [markdown]
# ### Plot the frequency per Arapuca of each BG type

# %%
# %matplotlib widget

plot="BOTH"
vd_plot = "BOTH" # "both", "cathode", "wall"

fig = plt.figure(1)
ax = fig.add_subplot(111)

fig2 = plt.figure(2)
ax2 = fig2.add_subplot(111)

NUM_COLORS = 13
cm = plt.get_cmap('tab20b')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
ax.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

ax.set_xlabel("Hit rate (kHz / channel)")
ax.set_xscale('log')
ax.set_ylabel("A.U.")
ax2.set_xlabel("Hit rate (kHz / channel)")
ax2.set_xscale('log')
ax2.set_ylabel("A.U.")
#ax.set_xlim(left=0.5, right=1000)


for i, type in enumerate(bg_types):
    print(i, type)
    
    total_len = 0
    lens = []
    total_len_ar = 0
    lens_ar = []
    
    for hit_list in bg_hit_list_per_event_per_type[i]:
        if detector == "HD" or (detector == "VD" and vd_plot == "both"):
            total_len += len(hit_list)
            lens.append(len(hit_list))
        elif detector == "VD" and vd_plot == "cathode":
            cathode_hits = [hit for hit in hit_list if hit[4] < 0]
            total_len += len(cathode_hits)
            lens.append(len(cathode_hits))
            num_channels = cathode_num_channels
        elif detector == "VD" and vd_plot == "wall":
            wall_hits = [hit for hit in hit_list if hit[4] > 0]
            total_len += len(wall_hits)
            lens.append(len(wall_hits))
            num_channels = wall_num_channels
    
    average_len = total_len / len(bg_hit_list_per_event_per_type[i])
    rate = average_len / bg_sample_length * 1/num_channels
    rate_per_area = rate / size_arapucas * 1000 # Hz / cm^2
    if rate < 0.1:
        ax.hist(np.array(lens) / bg_sample_length / num_channels, bins=np.linspace(0.1, 0.1, 70), label=type, density=True)
    if rate >= 0.01 and (plot=="BOTH" or plot=="xe"):
        ax2.hist(np.array(lens) / bg_sample_length / num_channels, bins=np.linspace(0.1, 2, 300), label=type, density=True)
    

    print(rate_per_area, "Hit rate (Hz / channel / cm^2)") #
    print(rate, "Hit rate (kHz / channel)") #
    print("Min:", np.min(lens)/bg_sample_length, "Max:", np.max(lens)/bg_sample_length)

    # Total rates:
    if detector == "VD":
        if vd_plot == "both":
            total_rate_mult = (352 * 2 + 320) / 184 * num_channels
            total_rate = rate * total_rate_mult
            total_rate_per_area = 0
        elif vd_plot == "cathode":
            total_rate = rate * cathode_rate_mult
            total_rate_per_area = rate_per_area * cathode_rate_mult
        elif vd_plot == "wall":
            total_rate = rate * wall_rate_mult
            total_rate_per_area = rate_per_area * wall_rate_mult
    elif detector == "HD":
        total_rate = rate * total_rate_mult * num_channels
        total_rate_per_area = rate_per_area * total_rate_mult 

    print(total_rate_per_area, "Total hit rate (kHz / cm^2)") #
    print(total_rate, "Total hit rate (kHz)") #

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

box = ax2.get_position()
ax2.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# 0 Ar39GenInLAr
# 0.0 Hit rate (Hz / channel / cm^2)
# 0.0 Hit rate (kHz / channel)
# /Users/pbarham/miniforge3/envs/nucenv/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/pbarham/Library/CloudStorage/OneDrive-Personal/workspace/cern/trigger/myway/scripts/collab_meeting.ipynb Cell 8 line 6
#      <a href='vscode-notebook-cell:/Users/pbarham/Library/CloudStorage/OneDrive-Personal/workspace/cern/trigger/myway/scripts/collab_meeting.ipynb#X10sZmlsZQ%3D%3D?line=58'>59</a> print(rate_per_area, "Hit rate (Hz / channel / cm^2)") #
#      <a href='vscode-notebook-cell:/Users/pbarham/Library/CloudStorage/OneDrive-Personal/workspace/cern/trigger/myway/scripts/collab_meeting.ipynb#X10sZmlsZQ%3D%3D?line=59'>60</a> print(rate, "Hit rate (kHz / channel)") #
# ---> <a href='vscode-notebook-cell:/Users/pbarham/Library/CloudStorage/OneDrive-Personal/workspace/cern/trigger/myway/scripts/collab_meeting.ipynb#X10sZmlsZQ%3D%3D?line=60'>61</a> print("Min:", np.min(lens)/bg_sample_length, "Max:", np.max(lens)/bg_sample_length)
#      <a href='vscode-notebook-cell:/Users/pbarham/Library/CloudStorage/OneDrive-Personal/workspace/cern/trigger/myway/scripts/collab_meeting.ipynb#X10sZmlsZQ%3D%3D?line=62'>63</a> # Total rates:
#      <a href='vscode-notebook-cell:/Users/pbarham/Library/CloudStorage/OneDrive-Personal/workspace/cern/trigger/myway/scripts/collab_meeting.ipynb#X10sZmlsZQ%3D%3D?line=63'>64</a> if detector == "VD":
#
# File <__array_function__ internals>:180, in amin(*args, **kwargs)
#
# File ~/miniforge3/envs/nucenv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2918, in amin(a, axis, out, keepdims, initial, where)
#    2802 @array_function_dispatch(_amin_dispatcher)
#    2803 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2804          where=np._NoValue):
#    2805     """
#    2806     Return the minimum of an array or minimum along an axis.
#    2807
#    (...)
#    2916     6
#    2917     """
# -> 2918     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2919                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniforge3/envs/nucenv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Distribution of PEs per hit

# %%
# %matplotlib widget
# What about the distribution/average PEs for each of these BG types?
for i, type in enumerate(bg_types):
    if type not in ["Ar39GenInLAr", "Kr85GenInLAr", "Rn222ChainInLAr", "NeutronGenInRock", "GammasGenInRock"]:
        continue
    print(i, type)
    
    avg_pes_list = []
    pes_list = []
    total_pes = []
    pes = []
    lens = 0
    
    for hit_list in bg_hit_list_per_event_per_type[i]:
        if len(hit_list) == 0:
            continue
        total_pes.extend(hit_list[:, -1])
        pes_list.append(hit_list[:, -1])
        avg_pes_list.append(np.mean(hit_list[:, -1]))
        lens += len(hit_list)
    
    average_pes = np.sum(total_pes) / lens
    rate = average_pes / bg_sample_length

    plt.hist(np.array(total_pes), bins=np.logspace(0, 2, 100), label=type, density=True, histtype='step', linewidth=2, linestyle='-')
    mean = np.mean(np.array(total_pes))
    mode = stats.mode(np.array(total_pes))[0][0]
    print("Type", mean, mode)
    
    #print(rate, "(PEs per ms)")
    # print(average_pes, "average PEs per hit")
    # print("Min:", np.min(total_pes), "Max:", np.max(total_pes))
    # print("--------")

# Also include the SN events (below 30 MeV)
avg_pes_list = []
pes_list = []
total_pes = []
pes = []
lens = 0
for i, hit_list in enumerate(sn_hit_list_per_event):
    # If energy is avove 30 MeV, skip
    if sn_info_per_event[i, 0] > 30:
        continue
    if len(hit_list) == 0:
        continue
    total_pes.extend(hit_list[:, -1])
    pes_list.append(hit_list[:, -1])
    avg_pes_list.append(np.mean(hit_list[:, -1]))
    lens += len(hit_list)

average_pes = np.sum(total_pes) / lens
rate = average_pes / bg_sample_length
plt.hist(np.array(total_pes), bins=np.logspace(0, 2, 100), label="SN events", density=True, histtype='step', linewidth=3, color="black")
mean = np.mean(np.array(total_pes))
mode = stats.mode(np.array(total_pes))[0][0]
print("SN", mean, mode)


# get the unique values and their frequency count
unique_values, occur_count = np.unique(np.array(total_pes), return_counts=True)

print(unique_values[1730:1740], occur_count[1730:1740])
print(np.diff(unique_values))

plt.xlabel("PEs")
#plt.xscale('log')
plt.yscale('log')
plt.legend()
# Out:
# 0 Ar39GenInLAr
# /var/folders/jn/g_gtx_qn7f9411g8ktr24lrh0000gn/T/ipykernel_10332/2231163916.py:27: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(np.array(total_pes))[0][0]
# Type 4.738234707543078 3.206515073776245
# 1 Kr85GenInLAr
# Type 4.829269977655434 3.1421213150024414
# 3 NeutronGenInRock
# Type 11.889454507794577 3.1231818199157715
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 43
#      40 lens = 0
#      41 for i, hit_list in enumerate(sn_hit_list_per_event):
#      42     # If energy is avove 30 MeV, skip
# ---> 43     if sn_info_per_event[i, 0] > 30:
#      44         continue
#      45     if len(hit_list) == 0:
#
# IndexError: index 47053 is out of bounds for axis 0 with size 47053
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Draw the cube

# %%
# %matplotlib widget
# Plot the opdet positions in 3D (184 OpChannels)
x, y, z = X_COORDS, Y_COORDS, Z_COORDS

# If VD, we have a proper 3D plot:
if detector == "VD":
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(y, z, x, c='purple', marker='o')

# If HD, we have a 2D plot:
elif detector == "HD":
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(z, y, c='purple', marker='o')
# Out:
# No such comm: 610bd1f6fd2f466bb478f3f3865cc90c
# No such comm: 90f506c84adb4c72a19b61ce25c890b6
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# No such comm: ac3d932122d34577a2bb3dcd58c04748

# %%
# Draw it for a specific bg type
# %matplotlib widget
arapuca_counts = np.zeros(num_channels)
tp = -1

for hit_list in bg_hit_list_per_event_per_type[tp]:
    for hit in hit_list:
        arapuca_counts[int(hit[2])] += 1


x, y, z = X_COORDS, Y_COORDS, Z_COORDS

event_num = len(bg_hit_list_per_event_per_type[tp])

if detector == "VD":

    # Frequency (kHz) per arapuca
    fig = plt.figure(10)

    ax = fig.add_subplot(111, projection='3d')
    scatter = ax.scatter(y, z, x, c=arapuca_counts/bg_sample_length/event_num, cmap='inferno', marker='o', alpha=1)
    plt.colorbar(scatter, label="Hit rate (kHz / arapuca)")
    print(min(arapuca_counts/bg_sample_length))
    ax.set_xlabel("Y (cm)")
    ax.set_ylabel("Z (cm)")
    ax.set_zlabel("X (cm)")

    # Frequency (kHz) per cm^2
    # fig = plt.figure(20)
    # ax = fig.add_subplot(111, projection='3d')
    # scatter = ax.scatter(y, z, x, c=arapuca_counts/bg_sample_length/size_arapucas, cmap='inferno', marker='o', alpha=1)
    # plt.colorbar(scatter, label="Hits/ms per cm^2")

elif detector == "HD":
    fig = plt.figure(10)
    ax = fig.add_subplot(111)
    scatter = ax.scatter(z, y, c=arapuca_counts/bg_sample_length/event_num, cmap='inferno', marker='o')
    plt.colorbar(scatter, label="Hit rate (kHz / arapuca)")

    plt.xlabel("Z (cm)")
    plt.ylabel("Y (cm)")
# Out:
# 24.11764705882353
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
